# %% [markdown]
# <a href="https://colab.research.google.com/github/Suriyasid007/Gen_AI58/blob/main/Spacy.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import spacy

# %%
my_nlp = spacy.load('en_core_web_sm')

# %%
doc = my_nlp('how the computer break down raw human. The readlable language to computer understndable language')

# %%
len(doc)
# Out:
# 15

# %%
doc.sents

# %%
for i in doc.sents:
  print(i.text)
# Out:
# how the computer break down raw human.
# The readlable language to computer understndable language

# %%
for i in doc:
  print(i,'__',i.lemma_)
# Out:
# how __ how
# the __ the
# computer __ computer
# break __ break
# down __ down
# raw __ raw
# human __ human
# . __ .
# The __ the
# readlable __ readlable
# language __ language
# to __ to
# computer __ computer
# understndable __ understndable
# language __ language

# %%
sentence = list(doc.sents)
print(sentence)
# for i in sentence:
#   print(i)
# Out:
# [how the computer break down raw human., The readlable language to computer understndable language]

# %%
sentence = list(doc.sents)[0]
for i in sentence:
  print(i)
# Out:
# how
# the
# computer
# break
# down
# raw
# human
# .

# %%
for i in sentence:
  print(i,'__',i.pos_)
# Out:
# how __ SCONJ
# the __ DET
# computer __ NOUN
# break __ VERB
# down __ ADP
# raw __ ADJ
# human __ NOUN
# . __ PUNCT

# %%
noun = []
for i in doc:
  if i.pos_ == 'NOUN':
    noun.append(i.text)
print(noun)
# Out:
# ['computer', 'human', 'language', 'language']

# %%
##random pairing

# %%
spacy.explain('VBD')
# Out:
# 'verb, past tense'
